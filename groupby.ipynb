# %%
import pandas as pd

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
gr1=df.groupby(by='lunch')
gr1

# %%
gr1.groups
# Out:
# {'free/reduced': Int64Index([  3,   7,   8,   9,  17,  18,  19,  21,  24,  25,
#              ...
#              976, 980, 988, 989, 990, 992, 993, 996, 997, 999],
#             dtype='int64', length=355),
#  'standard': Int64Index([  0,   1,   2,   4,   5,   6,  10,  11,  12,  13,
#              ...
#              982, 983, 984, 985, 986, 987, 991, 994, 995, 998],
#             dtype='int64', length=645)}

# %%
gr1=df.groupby(['lunch','race/ethnicity'])

# %%
gr1

# %%
gr1.groups
# Out:
# {('free/reduced',
#   'group A'): Int64Index([  3,  25,  61,  62,  72,  82, 228, 300, 327, 365, 368, 384, 395,
#              402, 428, 433, 442, 444, 467, 468, 489, 490, 575, 688, 705, 731,
#              741, 769, 805, 811, 830, 892, 902, 943, 972, 988],
#             dtype='int64'),
#  ('free/reduced',
#   'group B'): Int64Index([  7,   9,  17,  21,  39,  43,  68,  75,  81, 108, 116, 157, 160,
#              162, 167, 176, 178, 188, 198, 199, 208, 209, 218, 279, 288, 295,
#              308, 335, 338, 396, 424, 461, 507, 514, 519, 551, 558, 564, 568,
#              578, 596, 621, 626, 636, 642, 667, 704, 715, 722, 730, 737, 744,
#              772, 775, 782, 818, 823, 838, 842, 843, 856, 882, 896, 897, 914,
#              923, 948, 976, 980],
#             dtype='int64'),
#  ('free/reduced',
#   'group C'): Int64Index([ 18,  19,  40,  54,  55,  59,  73,  86,  91,  93,
#              ...
#              908, 913, 921, 929, 930, 933, 940, 963, 996, 997],
# ...

# %%
for lunch,df in gr1:
    print(lunch)
    print(df)
# Out:
# ('free/reduced', 'group A')
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 61     male        group A            some high school  free/reduced
# 62     male        group A          associate's degree  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 82     male        group A                some college  free/reduced
# 228    male        group A            some high school  free/reduced
# 300    male        group A                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 365    male        group A           bachelor's degree  free/reduced
# 368  female        group A            some high school  free/reduced
# 384  female        group A            some high school  free/reduced
# ...

# %%
list(gr1)
# Out:
# [(('free/reduced', 'group A'),
#        gender race/ethnicity parental level of education         lunch  \
#   3      male        group A          associate's degree  free/reduced
#   25     male        group A             master's degree  free/reduced
#   61     male        group A            some high school  free/reduced
#   62     male        group A          associate's degree  free/reduced
#   72   female        group A          associate's degree  free/reduced
#   82     male        group A                some college  free/reduced
#   228    male        group A            some high school  free/reduced
#   300    male        group A                some college  free/reduced
#   327    male        group A                some college  free/reduced
#   365    male        group A           bachelor's degree  free/reduced
#   368  female        group A            some high school  free/reduced
#   384  female        group A            some high school  free/reduced
# ...

# %%
dict(list(gr1))
# Out:
# {('free/reduced',
#   'group A'):      gender race/ethnicity parental level of education         lunch  \
#  3      male        group A          associate's degree  free/reduced
#  25     male        group A             master's degree  free/reduced
#  61     male        group A            some high school  free/reduced
#  62     male        group A          associate's degree  free/reduced
#  72   female        group A          associate's degree  free/reduced
#  82     male        group A                some college  free/reduced
#  228    male        group A            some high school  free/reduced
#  300    male        group A                some college  free/reduced
#  327    male        group A                some college  free/reduced
#  365    male        group A           bachelor's degree  free/reduced
#  368  female        group A            some high school  free/reduced
#  384  female        group A            some high school  free/reduced
# ...

# %%
df.groupby('gender').get_group('male')
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 34    male        group E                some college  standard
# 35    male        group E          associate's degree  standard
# 50    male        group E                some college  standard
# 76    male        group E            some high school  standard
# 83    male        group E          associate's degree  standard
# 107   male        group E          associate's degree  standard
# 124   male        group E                some college  standard
# 137   male        group E                 high school  standard
# 171   male        group E            some high school  standard
# 186   male        group E                 high school  standard
# 206   male        group E           bachelor's degree  standard
# 207   male        group E                 high school  standard
# 214   male        group E                 high school  standard
# 233   male        group E            some high school  standard
# ...

# %%
df.groupby('race/ethnicity')

# %%
gr1.sum()
# Out:
#                              math score  reading score  writing score
# lunch        race/ethnicity
# free/reduced group A               1988           2180           2059
#              group B               3963           4414           4245
#              group C               6431           7229           7001
#              group D               5806           6311           6313
#              group E               2729           2818           2755
# standard     group A               3497           3576           3519
#              group B               8093           8383           8219
#              group C              14133          14815          14636
#              group D              11843          12037          12065
#              group E               7606           7406           7242

# %%
gr1.mean()
# Out:
#                              math score  reading score  writing score
# lunch        race/ethnicity
# free/reduced group A          55.222222      60.555556      57.194444
#              group B          57.434783      63.971014      61.521739
#              group C          56.412281      63.412281      61.412281
#              group D          61.115789      66.431579      66.452632
#              group E          66.560976      68.731707      67.195122
# standard     group A          65.981132      67.471698      66.396226
#              group B          66.884298      69.280992      67.925620
#              group C          68.941463      72.268293      71.395122
#              group D          70.916168      72.077844      72.245509
#              group E          76.828283      74.808081      73.151515

# %%
gr1.describe()
# Out:
#                             math score                                     \
#                                  count       mean        std   min    25%
# lunch        race/ethnicity
# free/reduced group A              36.0  55.222222  14.138319  28.0  44.75
#              group B              69.0  57.434783  15.834139   8.0  49.00
#              group C             114.0  56.412281  14.313068   0.0  47.25
#              group D              95.0  61.115789  13.936683  26.0  52.00
#              group E              41.0  66.560976  17.096855  32.0  55.00
# standard     group A              53.0  65.981132  13.216381  45.0  56.00
#              group B             121.0  66.884298  14.215127  19.0  58.00
#              group C             205.0  68.941463  13.191890  29.0  59.00
#              group D             167.0  70.916168  12.372440  40.0  62.50
#              group E              99.0  76.828283  13.848333  30.0  68.00
#
# ...

# %%
gr1.agg(['sum','max','min'])
# Out:
#                                                                         gender  \
#                                                                            sum
# lunch        race/ethnicity
# free/reduced group A         malemalemalemalefemalemalemalemalemalemalefema...
#              group B         malefemalefemalefemalemalemalemalemalemalefema...
#              group C         malefemalemalefemalefemalefemalemalefemalemale...
#              group D         malemalefemalefemalefemalemalefemalemalefemale...
#              group E         femalefemalemalemalemalefemalemalefemalefemale...
# standard     group A         malefemalefemalemalefemalemalefemalemalemalema...
#              group B         femalefemalefemalefemalefemalemalefemalefemale...
#              group C         femalemalemalefemalemalefemalefemalemalefemale...
#              group D         malemalemalefemalefemalemalefemalemalemalemale...
# ...
